# %% [markdown]
# ## Auto Script

# %% [markdown]
#     This script will automatically select the username to whom to send request everyday! The input will be the hashtag.
#     This script will do the following things.
#
#     1. Extract the list of people to send request from SQL file,
#     2. Extract my followers and followee list
#     3. Look through these list to confirm that the person I am sending request to is not in this list
#     4. Check if the account is open or close. I will send request only to open account.
#     5. Check the model I created and tell whether I should follow them or not.
#     6. Follow them
#     7. Like there picture
#     8. Save the list in database (date, username).
#     # TODO
#     9. Use this list to unfollow the person where date is of 7 day before the current date.

# %%
# Change directory
import os
os.chdir('C:\\Users\\PC\\Desktop\\Instagram_production')

# Necessary imports
from datetime import datetime, timedelta
from itertools import dropwhile, takewhile
from instaloader import Instaloader, Profile
from src.insta import InstagramBot
from sklearn.externals.joblib import load
from src.FeatureExtraction import featureExtraction
import sqlite3 as db
import numpy as np
import pandas as pd
from selenium.common.exceptions import TimeoutException, WebDriverException, NoSuchElementException

# # today date
today = datetime.today()

# Connect to a database (or create one if it doesn't exist) for saving the list in database
conn = db.connect('data/sqldb/Ig_Data.db')
# Create a 'cursor' for executing commands
c = conn.cursor()

# query = '''SELECT * FROM UsersData WHERE date = {}{}{}'''.format("'", today.date(), "'")
# dataframe = pd.read_sql(query, conn)
# users = dataframe['username'].values


# print('Step 1 Completed...')

# L = Instaloader()
# USER = 'deliacarras' # user with login done
# PASSWORD = 'Abhijeet@163' # password of user
# USERNAME = '_hernando_malik' # the username whose details we need to search. 
# L.login(USER, PASSWORD)
# # Extracting list of my follower and followees !!
# profile = Profile.from_username(L.context, USERNAME)

# followers = []
# for follower in profile.get_followers():
#     followers.append(follower.username)
    
# followees = []
# for followee in profile.get_followees():
#     followees.append(followee.username)
    
# print('Step 2 completed...')
    
# ## Look through the list and confirm that the person I am sending request is not in the list !
# # We will only consider toFollow list and will delete other list
# # TODO: Below make a program where check the user name of the person to whom I followed in SQL File
# ###     If he is also in users, remove him. 
 

# toFollow = []
# for user in users:
#     if user in followers or user in followees:
#         pass
#     else: 
#         toFollow.append(user)

# print('Step 3 completed...')
        

# del users


# Login using my account and checking for profile information
username = '_hernando_malik'
_pass = 'Abhijeet@163'

insta = InstagramBot(username, _pass)
insta.login()

# model = load('model/lgm.model')
# for user in toFollow:
#     # Cleaning the data , removing zero count for follower and followings .
#     data = pd.DataFrame()
#     data = dataframe[dataframe['username'] == user]
#     data = data[['username', 'privacy', 'post', 'followings', 'followers']]
#     data = data[(data.followings != 0) & (data.followers != 0) & (data.privacy == "Open")]
#     if len(data) == 0:
#         pass
#     else:
#         feature = featureExtraction(data)
#         df = feature.exeFeatureExtraction()
#         X = df.iloc[:, :7].values
#         model_flag = model.predict(X)[0]
#         if model_flag == 0:
#             try:
#                 insta.follow(user)
#                 insta.likePhotos(2 + np.random.randint(2, 5), user)
#                 query = 'INSERT INTO Hernando_Follow_request VALUES ({}{}{}, {}{}{})'.format("'",today.date(),"'", '"',user,'"')
#                 c.execute(query)
#                 conn.commit()
#                 loop_break_flag = 0
#                 if loop_break_flag == 30:
#                     print('loop Broken : The End')
#                     break
#                 else:
#                     loop_break_flag += 1
#             except (WebDriverException, NoSuchElementException, TimeoutException):
#                 pass
#         else:
#             pass

# For unfollowing the users who was followed 7 days before. 
sevenDayBefore = datetime.today() + timedelta(days = -6)
query = '''SELECT * FROM Hernando_Follow_request WHERE requestDate = "{}"'''.format(sevenDayBefore.date())
unfollow = pd.read_sql_query(query, conn)
toUnfollow = unfollow['username'].values
for user in toUnfollow:
#     if user in followees:
    try: 
        insta.unfollow(user)
    except NoSuchElementException:
        print("Check these user manually: ", user)
#     else: 
#         print("These users are not in the followees list: ", user)
# Out:
# C:\Users\PC\Anaconda3\envs\Twitter\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)
# C:\Users\PC\Anaconda3\envs\Twitter\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\Twitter\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# OperationalError: near "<": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-1-ee3c83133c60> in <module>
#     109 sevenDayBefore = datetime.today() + timedelta(days = -7)
#     110 query = '''SELECT * FROM Hernando_Follow_request WHERE requestDate =< "{}"'''.format(sevenDayBefore.date())
# --> 111 unfollow = pd.read_sql_query(query, conn)
#     112 toUnfollow = unfollow['username'].values
#     113 for user in toUnfollow:
#
# ~\Anaconda3\envs\Twitter\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\Anaconda3\envs\Twitter\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1631
#    1632         args = _convert_params(sql, params)
# -> 1633         cursor = self.execute(*args)
#    1634         columns = [col_desc[0] for col_desc in cursor.description]
#    1635
#
# ~\Anaconda3\envs\Twitter\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1596
#    1597             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1598             raise ex from exc
#    1599
#    1600     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT * FROM Hernando_Follow_request WHERE requestDate =< "2020-04-10"': near "<": syntax error

# %%
sevenDayBefore = datetime.today() + timedelta(days = -5)
query = '''SELECT * FROM Hernando_Follow_request WHERE requestDate = "{}"'''.format(sevenDayBefore.date())
query = '''SELECT * FROM Hernando_Follow_request'''
unfollow = pd.read_sql_query(query, conn)
toUnfollow = unfollow['username'].values
for user in toUnfollow:
#     if user in followees:
    try: 
        insta.unfollow(user)
    except (NoSuchElementException, WebDriverException):
        print("Check these user manually: ", user)
#     else: 
#         print("These users are not in the followees list: ", user)
# Out:
# Check these user manually:  acroquet1
# Check these user manually:  ajouahimounir
# Check these user manually:  alex.utopique.moon
# Check these user manually:  alice_dechainee
# Check these user manually:  ana_is_owen
# Check these user manually:  annelaurelescieux
# Check these user manually:  arurima___sengupta
# Check these user manually:  aubergeduvalmarie66
# Check these user manually:  ayoub_lahrichii
# Check these user manually:  bilal_oubida
# Check these user manually:  by_roxyy
# Check these user manually:  c__pierre
# Check these user manually:  charliined
# Check these user manually:  chay_de__
# Check these user manually:  chefwilliamweiss
# Check these user manually:  chevalierakram
# Check these user manually:  chocolatino.777
# Check these user manually:  cliches_phile
# Check these user manually:  daniel.jora
# Check these user manually:  delangeladrianj
# Check these user manually:  destinybandana
# Check these user manually:  digichris
# Check these user manually:  e_m_e_r_i_c_k_9_3_
# Check these user manually:  elenivagelatos
# Check these user manually:  emsrt_
# Check these user manually:  eric.magnier
# Check these user manually:  fpatoune
# Check these user manually:  guerradaniel3744
# Check these user manually:  heat.affected_zone
# Check these user manually:  hendriksjonathan
# Check these user manually:  hortense_stv
# Check these user manually:  huellas.en.el.camino
# Check these user manually:  jailysrgz
# Check these user manually:  jcefit01
# Check these user manually:  _1.seth_
# Check these user manually:  _frabarcaphotographer_
# Check these user manually:  _karma.shop
# Check these user manually:  _oliiviax
# Check these user manually:  _ridershub_
# Check these user manually:  2frugalfoodies
# Check these user manually:  adav315
# Check these user manually:  aden_dubin
# Check these user manually:  ahothouseflower
# Check these user manually:  aidamtoro
# Check these user manually:  aiden_molina69
# Check these user manually:  anarkaliii
# Check these user manually:  ash_a08
# Check these user manually:  ashleychristinaa_
# Check these user manually:  becktorres_
# Check these user manually:  blurredpixels_ig
# Check these user manually:  boodahspliff
# Check these user manually:  bradley.beal_
# Check these user manually:  brendan.barry
# Check these user manually:  brianreinert
# Check these user manually:  mrsrobinson0309
# Check these user manually:  neil_le_bihan_
# Check these user manually:  olivermarshall
# Check these user manually:  studioivyone
# Check these user manually:  mrsrobinson0309
# Check these user manually:  neil_le_bihan_
# Check these user manually:  olivermarshall
# Check these user manually:  studioivyone
# Check these user manually:  andy_rebel_
# Check these user manually:  azaablive
# Check these user manually:  bekim7888
# Check these user manually:  andy_rebel_
# Check these user manually:  azaablive
# Check these user manually:  bekim7888
# Check these user manually:  craft_beauty_jewellery
# Check these user manually:  dbn4
# Check these user manually:  ddiraqi_man554
# Check these user manually:  defensestore
# Check these user manually:  fitness_bylisa
# Check these user manually:  fsyren28
# Check these user manually:  grundsunds.hk
# Check these user manually:  hideindarkness
# Check these user manually:  kraina_memow11
# Check these user manually:  miamia_77
# Check these user manually:  neondaemonband
# Check these user manually:  __aminah.__
# Check these user manually:  sivatskayamila.fan
# Check these user manually:  _kevinbarrios
# Check these user manually:  aguilarjose.1
# Check these user manually:  agus_paredes.16
# Check these user manually:  aleoliveira_07
# Check these user manually:  amro_you
# Check these user manually:  andres_tellez96
# Check these user manually:  andrespe21
# Check these user manually:  axelribot17
# Check these user manually:  axelvitullo
# Check these user manually:  bernardoa013
# Check these user manually:  blandon190
# Check these user manually:  14___nick___14
# Check these user manually:  awildbagtea
# Check these user manually:  _matteo_mele_
# Check these user manually:  _perica14_
# Check these user manually:  aleksi_ilmari_seppala
# Check these user manually:  athakeiza.pootis
# Check these user manually:  awildbagtea
# Check these user manually:  babypupuboo_
# Check these user manually:  black.stasya
# Check these user manually:  axel_julian_nunez
# Check these user manually:  _la_salvi_
# Check these user manually:  _.alexandraa12._
# Check these user manually:  5.7chxwz
# Check these user manually:  amor.luxscaax
# Check these user manually:  cass_prieto
# Check these user manually:  j.mart89
# Check these user manually:  niamh.bella98
# Check these user manually:  documentarykurdi
# Check these user manually:  cari.cruz.165
# Check these user manually:  cucina_e_fuochi
# Check these user manually:  go_suntaek
# Check these user manually:  02gyu_
# Check these user manually:  0_o.erik_71
# Check these user manually:  184__dh
# Check these user manually:  77xoxoo
# Check these user manually:  ____gena81
# Check these user manually:  _lou.ruby_
# Check these user manually:  _ye._.dam
# Check these user manually:  adsup_
# Check these user manually:  aj.deng_
# Check these user manually:  alldformarket
# Check these user manually:  1571_elizabeth
# Check these user manually:  _asumi.k_
# Check these user manually:  abc90308
# Check these user manually:  cesar_olivera_latorre
# Check these user manually:  cypr_ian
# Check these user manually:  delimanana
# Check these user manually:  drew_mayes_official
# Check these user manually:  evanbuggle
# Check these user manually:  grace_c._
# Check these user manually:  haruto6579
# Check these user manually:  hayabusaknight72
# Check these user manually:  hellyeah.jpeg
# Check these user manually:  hoesuave
# Check these user manually:  iamnickclar
# Check these user manually:  leslie_honk
# Check these user manually:  mangoloww
# Check these user manually:  miyu0402
# Check these user manually:  moiib2
# Check these user manually:  nanaisme105
# Check these user manually:  omg_toasty
# Check these user manually:  pupa_chang
# Check these user manually:  rhooker15
# Check these user manually:  scandalsound
# Check these user manually:  sinob6752
# Check these user manually:  sobakasu_27
# Check these user manually:  subspclr4
# Check these user manually:  takehiro_snap
# Check these user manually:  112.2k
# Check these user manually:  jiyeon1026
# Check these user manually:  lee_h7.7
# Check these user manually:  mr_6.0_feet
# Check these user manually:  _kdm._.291
# Check these user manually:  ally_suzuke
# Check these user manually:  anapauladesousavasconcelosv
# Check these user manually:  bryanignacioh
# Check these user manually:  catia_muller12_
# Check these user manually:  claudioitasilva
# Check these user manually:  francentrodebeleza
# Check these user manually:  gisagiuvanellimakeup
# Check these user manually:  hhh_jae
# Check these user manually:  jngh4n
# Check these user manually:  joyceprazereslima
# Check these user manually:  karylenmakeup
# Check these user manually:  kassicooper
# Check these user manually:  _caprisunpapi
# Check these user manually:  _dchance
# Check these user manually:  alejandro_tp
# Check these user manually:  alessi_one
# Check these user manually:  buddy273
# Check these user manually:  cutlassgreg
# Check these user manually:  davinsig
# Check these user manually:  evo9_tc
# Check these user manually:  fongy_808
# Check these user manually:  hector.castillo.9638
# Check these user manually:  hessian_for_hire
# Check these user manually:  itzzzrichy
# Check these user manually:  jakolam
# Check these user manually:  jazz_w2222

# %%
unfollow
# Out:
#     requestDate              username
# 0    2020-04-08             acroquet1
# 1    2020-04-08         ajouahimounir
# 2    2020-04-08    alex.utopique.moon
# 3    2020-04-08       alice_dechainee
# 4    2020-04-08           ana_is_owen
# ..          ...                   ...
# 440  2020-04-17  hector.castillo.9638
# 441  2020-04-17      hessian_for_hire
# 442  2020-04-17            itzzzrichy
# 443  2020-04-17               jakolam
# 444  2020-04-17            jazz_w2222
#
# [445 rows x 2 columns]

# %% [markdown]
#                                                     -------------END --------------
